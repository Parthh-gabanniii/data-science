# %%
import pandas as pd
import numpy as np
df = pd.read_csv("student_1.csv")
print(df.head())
print("\n\n")

print(df.dropna(axis=0))


print(df.fillna(0))
print(df['gender'].fillna('No Gender'))
print(df['FDS'].fillna(df['FDS'].mean()))
print(df['ML'].fillna(df['ML'].mean()))
print(df['AI'].fillna(df['AI'].mean()))
print(df['P_S'].fillna(df['P_S'].mean()))
print(df['DMBI'].fillna(df['DMBI'].mean()))
# Out:
#   Student_name Gender Enrollment No.   FDS    ML    AI   P_S  DMBI  \
# 0      Parth        M    ET21BTAI001  89.0  90.0  78.0  80.0  75.0
# 1      Aryan C      M    ET21BTAI002  75.0  78.0  75.0  91.0  90.0
# 2        Rohit      M    ET21BTAI003  89.0  90.0  85.0  82.0  78.0
# 3      Prayesh      M    ET21BTAI004  89.0  90.0  87.0  81.0  78.0
# 4        Urvil      M    ET21BTAI005  75.0  78.0  75.0  78.0  87.0
#
#    Mobile No.     City  sem1  sem2  sem3  sem4  sem5
# 0  9984364546    Surat  89.0  90.0  78.0  80.0  75.0
# 1  9856372889  Vadodra  75.0  78.0  75.0  91.0  90.0
# 2  9843647464    Surat  89.0  90.0  85.0  82.0  78.0
# 3  9313980494    Surat  89.0  90.0  87.0  81.0  78.0
# 4  9857372904  Vadodra  75.0  78.0  75.0  78.0  87.0
#
#
#
#    Student_name Gender Enrollment No.        FDS         ML         AI  \
# 0       Parth        M    ET21BTAI001  89.000000  90.000000  78.000000
# 1       Aryan C      M    ET21BTAI002  75.000000  78.000000  75.000000
# ...
